# %%
import urllib
import json

# %%
class office_data:
    ask = "https://declarator.org/api/v1/search/sections/?office="
    
    def __init__(self, data, f):
        self.data = data
        self.family = f
        
#     def find_children(self):
#         return []

#     def __init__(self, office_id):
#         self.office_id = office_id
#         data_struct = {} 
#         data = {'next':self.ask+str(office_id)}
#         while data["next"]:
#             with urllib.request.urlopen(data["next"]) as url:
#                 data = json.loads(url.read().decode())
#             for i in data["results"]:
#                 if i["main"]["year"] not in data_struct:
#                     data_struct[i["main"]["year"]] = []
#                 data_struct[i["main"]["year"]].append(i)
#             print(data["next"])
#         #надо обойти всех child и вызвать одну из функций sort
#         child_list = self.find_children()
#         for i in child_list:
#             child_data = get_data_office(i)
#             for j in child_data:
#                 if j not in data_struct:
#                     data_struct[j] = []
#                 data_struct[j] += child_data[j]

#         self.data = data_struct # данные всех деклараций по годам
#         self.family = 0 # учитывать ли семью
        
    def true_avg(self, typ):
        years = self.data.keys()
        res = [None]  * len(years)
        for i, year in enumerate(years):
            curr_sum = 0
            curr_amount = 0
            for declaration in self.data[year]:
                for pep in declaration[typ]:
                    inc = pep['size']
                    if self.family or (pep['relative'] == None):
                        if inc != None:
                            curr_sum += inc
                curr_amount += 1
            if curr_amount != 0:
                res[i] = curr_sum / curr_amount
        return res
        
    def gender_avg(self, typ):
        years = self.data.keys()
        males = [None] * len(years)
        females = [None] * len(years)
        for i, year in enumerate(years):
            male_sum = 0
            female_sum = 0
            male_amount = 0
            female_amount = 0
            for declaration in self.data[year]:
                gender = declaration['main']['person']['gender']
                for pep in declaration[typ]:
                    inc = pep['size']
                    if self.family or (pep['relative'] == None):
                        if inc != None:
                            if gender == 'M':
                                male_sum += inc
                            elif gender == 'F':
                                female_sum += inc
                if gender == 'M':
                    male_amount += 1
                elif gender == 'F':
                    female_amount += 1
            if male_amount != 0:
                males[i] = male_sum / male_amount
            if female_amount != 0:
                females[i] = female_sum / female_amount
        
        return males, females
        
    def party_avg(self, typ):
        parties = set()
        years = self.data.keys()
        for year in years:
            for declaration in self.data[year]:
                party = declaration['main']['party']
                if party != party or party == None:
                    parties.add('Нет Данных')
                else:
                    parties.add(party['name'])
        parties = list(parties)
        res = {par : [None] * len(years) for par in parties}
        for i, year in enumerate(years):
            sums = {par : 0 for par in parties}
            amounts = {par : 0 for par in parties}
            for declaration in self.data[year]:
                party = declaration['main']['party']
                if party != party or party == None:
                    party = 'Нет Данных'
                else:
                    party = party['name']
                for pep in declaration[typ]:
                    inc = pep['size']
                    if self.family or (pep['relative'] == None):
                        if inc != None:
                            sums[party] += inc
                amounts[party] += 1
            for party in parties:
                if amounts[party] != 0:
                    res[party][i] = sums[party] / amounts[party]
        return parties, list(res.values())
    #self.data - список по годам деклараций людей

# %%
office = office_data(data, False)

# %%
office.party_avg("incomes")
# Out:
# (['Единая Россия', 'Нет Данных'],
#  [[975657.0,
#    1063445.0,
#    1215654.67,
#    1397083.65,
#    1769658.0,
#    2213239.15,
#    3031778.9,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    2769537.14,
#    1567386.81,
#    1478636.39,
#    1445398.08]])

# %%
office = office_data(data, True)

# %%
office.party_avg('incomes')
# Out:
# (['Единая Россия', 'Нет Данных'],
#  [[1102094.0,
#    1210288.0,
#    1511234.16,
#    1710425.38,
#    2109819.0,
#    2730143.1799999997,
#    3608056.82,
#    None,
#    None,
#    None,
#    None],
#   [None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    3396191.98,
#    2281861.84,
#    1632852.5799999998,
#    1503484.85]])

# %%
data[2009]
# Out:
# [{'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1071362.0},
#    {'comment': '', 'relative': {'id': 2, 'name': 'Супруг(а)'}, 'size': 131.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Иванов',
#     'gender': 'M',
#     'given_name': 'Николай',
#     'id': 19812,
#     'name': 'Иванов Николай Алексеевич',
#     'patronymic_name': 'Алексеевич'},
#    'year': 2009},
#   'real_estates': [{'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 1400.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 78.8,
#     'type': {'id': 3, 'name': 'Жилой дом'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': []},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1089814.0},
#    {'comment': '',
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'size': 274044.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Куханов',
#     'gender': 'M',
#     'given_name': 'Юрий',
#     'id': 19815,
#     'name': 'Куханов Юрий Владимирович',
#     'patronymic_name': 'Владимирович'},
#    'year': 2009},
#   'real_estates': [{'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 7430.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': 'служебный',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 9, 'name': 'В пользовании'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': 60.9,
#     'type': {'id': 3, 'name': 'Жилой дом'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': 0.333333333333333,
#     'square': 1171.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': 0.333333333333333,
#     'square': 60.9,
#     'type': {'id': 3, 'name': 'Жилой дом'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 4, 'name': 'Дочь'},
#     'share': 0.333333333333333,
#     'square': 1171.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 4, 'name': 'Дочь'},
#     'share': 0.333333333333333,
#     'square': 1171.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 4, 'name': 'Дочь'},
#     'share': 0.333333333333333,
#     'square': 60.9,
#     'type': {'id': 3, 'name': 'Жилой дом'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 4, 'name': 'Дочь'},
#     'share': 0.333333333333333,
#     'square': 60.9,
#     'type': {'id': 3, 'name': 'Жилой дом'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 1581, 'name': 'Ipsum'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1261682.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Морозов',
#     'gender': 'M',
#     'given_name': 'Евгений',
#     'id': 19813,
#     'name': 'Морозов Евгений Викторович',
#     'patronymic_name': 'Викторович'},
#    'year': 2009},
#   'real_estates': [{'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 4, 'name': 'Наём (аренда)'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': 64.0,
#     'type': {'id': 3, 'name': 'Жилой дом'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 1523, 'name': 'Allion'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1480673.0},
#    {'comment': '',
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'size': 403169.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Мылицын',
#     'gender': 'M',
#     'given_name': 'Николай',
#     'id': 19803,
#     'name': 'Мылицын Николай Викторович',
#     'patronymic_name': 'Викторович'},
#    'year': 2009},
#   'real_estates': [{'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 4, 'name': 'Наём (аренда)'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': 80.0,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 99.0,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': None,
#     'square': 65.8,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': 'погребная ячейка',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': None,
#     'square': 3.0,
#     'type': {'id': 6, 'name': 'Иное'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': []},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1211452.0},
#    {'comment': '',
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'size': 567185.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Поносов',
#     'gender': 'M',
#     'given_name': 'Виктор',
#     'id': 19806,
#     'name': 'Поносов Виктор Наумович',
#     'patronymic_name': 'Наумович'},
#    'year': 2009},
#   'real_estates': [{'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': None,
#     'share': 0.25,
#     'square': 69.8,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': None,
#     'square': 64.0,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': 0.25,
#     'square': 69.8,
#     'type': {'id': 4, 'name': 'Квартира'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 639, 'name': 'Focus'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 815916.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Пустогачев',
#     'gender': 'M',
#     'given_name': 'Александр',
#     'id': 19808,
#     'name': 'Пустогачев Александр Вадимович',
#     'patronymic_name': 'Вадимович'},
#    'year': 2009},
#   'real_estates': [{'comment': 'служебная',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 9, 'name': 'В пользовании'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': 61.0,
#     'type': {'id': 4, 'name': 'Квартира'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 1537, 'name': 'Camry'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1123521.0},
#    {'comment': '',
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'size': 100000.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Степанов',
#     'gender': 'M',
#     'given_name': 'Дмитрий',
#     'id': 19807,
#     'name': 'Степанов Дмитрий Юрьевич',
#     'patronymic_name': 'Юрьевич'},
#    'year': 2009},
#   'real_estates': [{'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 1184.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 142.0,
#     'type': {'id': 3, 'name': 'Жилой дом'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 1537, 'name': 'Camry'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1259109.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Сторчак',
#     'gender': 'F',
#     'given_name': 'Наталья',
#     'id': 19809,
#     'name': 'Сторчак Наталья Владимировна',
#     'patronymic_name': 'Владимировна'},
#    'year': 2009},
#   'real_estates': [{'comment': 'служебная',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 9, 'name': 'В пользовании'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': None,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 50.5,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 24.0,
#     'type': {'id': 2, 'name': 'Гараж'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 1820, 'name': 'Таврия'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1097393.0},
#    {'comment': '', 'relative': None, 'size': 243572.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Суразов',
#     'gender': 'M',
#     'given_name': 'Геннадий',
#     'id': 19811,
#     'name': 'Суразов Геннадий Дмитриевич',
#     'patronymic_name': 'Дмитриевич'},
#    'year': 2009},
#   'real_estates': [{'comment': 'совместная с супругой',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 22, 'name': 'Совместная собственность'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 550.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': None,
#     'share': 0.5,
#     'square': 1367.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': 'служебный',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 9, 'name': 'В пользовании'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': 61.7,
#     'type': {'id': 3, 'name': 'Жилой дом'}},
#    {'comment': 'совместная с супругой',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 22, 'name': 'Совместная собственность'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 97.6,
#     'type': {'id': 3, 'name': 'Жилой дом'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': None,
#     'share': 0.333333333333333,
#     'square': 61.0,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': 0.5,
#     'square': 1367.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': 'совместная с супругом',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 22, 'name': 'Совместная собственность'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': None,
#     'square': 5500.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': 'совместная с супругом',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 22, 'name': 'Совместная собственность'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': None,
#     'square': 97.6,
#     'type': {'id': 3, 'name': 'Жилой дом'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': 0.333333333333333,
#     'square': 61.0,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 3, 'name': 'Сын'},
#     'share': 0.333333333333333,
#     'square': 61.0,
#     'type': {'id': 4, 'name': 'Квартира'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 1581, 'name': 'Ipsum'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 839364.0},
#    {'comment': '', 'relative': None, 'size': 47509.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Тобоев',
#     'gender': 'M',
#     'given_name': 'Аржан',
#     'id': 19814,
#     'name': 'Тобоев Аржан Иванович',
#     'patronymic_name': 'Иванович'},
#    'year': 2009},
#   'real_estates': [{'comment': 'служебный',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 9, 'name': 'В пользовании'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': 67.4,
#     'type': {'id': 3, 'name': 'Жилой дом'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 1576, 'name': 'Harrier'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 977256.0},
#    {'comment': '',
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'size': 97976.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Тужеметов',
#     'gender': 'M',
#     'given_name': 'Дмитрий',
#     'id': 19810,
#     'name': 'Тужеметов Дмитрий Валерьевич',
#     'patronymic_name': 'Валерьевич'},
#    'year': 2009},
#   'real_estates': [{'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 6100.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 98.8,
#     'type': {'id': 3, 'name': 'Жилой дом'}},
#    {'comment': 'служебная',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 9, 'name': 'В пользовании'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': 60.5,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': 'земля сельхозназначения',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': None,
#     'square': 66000.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 1460, 'name': 'Outback'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}},
#    {'brand': {'id': 1559, 'name': 'Cresta'},
#     'comment': '',
#     'manufacture_year': None,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1559350.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Четвернин',
#     'gender': 'M',
#     'given_name': 'Олег',
#     'id': 19805,
#     'name': 'Четвернин Олег Александрович',
#     'patronymic_name': 'Александрович'},
#    'year': 2009},
#   'real_estates': [{'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 890.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': None,
#     'share': 0.5,
#     'square': 1440.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': 'в залоге в банке по кредиту',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 20, 'name': 'Индивидуальная'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 65.0,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': 'служебная',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 9, 'name': 'В пользовании'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': 65.0,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': None,
#     'share': 0.5,
#     'square': 67.0,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 3, 'name': 'Сын'},
#     'share': 0.5,
#     'square': 1440.0,
#     'type': {'id': 1, 'name': 'Земельный участок'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 21, 'name': 'Долевая собственность'},
#     'region': None,
#     'relative': {'id': 3, 'name': 'Сын'},
#     'share': 0.5,
#     'square': 67.0,
#     'type': {'id': 4, 'name': 'Квартира'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': [{'brand': {'id': 732, 'name': 'Orthia'},
#     'comment': '',
#     'manufacture_year': 1996,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}},
#    {'brand': {'id': 2231, 'name': 'Land Cruiser 80'},
#     'comment': '',
#     'manufacture_year': 1996,
#     'name': '',
#     'relative': None,
#     'type': {'id': 1, 'name': 'Автомобиль легковой'}}]},
#  {'bonds': [],
#   'incomes': [{'comment': '', 'relative': None, 'size': 1066687.0},
#    {'comment': '',
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'size': 23070.0}],
#   'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#    'office': {'id': 10,
#     'name': 'Прокуратура Республики Алтай',
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'type': {'id': 18, 'name': 'Региональный, без структуры'},
#     'url': 'http://www.prokuratura.gorny.ru/'},
#    'party': None,
#    'person': {'family_name': 'Шухин',
#     'gender': 'M',
#     'given_name': 'Сергей',
#     'id': 19804,
#     'name': 'Шухин Сергей Николаевич',
#     'patronymic_name': 'Николаевич'},
#    'year': 2009},
#   'real_estates': [{'comment': 'совместная с супругой',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 22, 'name': 'Совместная собственность'},
#     'region': None,
#     'relative': None,
#     'share': None,
#     'square': 37.9,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': '',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#     'region': {'id': 6, 'name': 'Республика Алтай'},
#     'relative': None,
#     'share': None,
#     'square': 56.8,
#     'type': {'id': 4, 'name': 'Квартира'}},
#    {'comment': 'совместная с супругом',
#     'country': 'Россия',
#     'name': '',
#     'own_type': {'id': 22, 'name': 'Совместная собственность'},
#     'region': None,
#     'relative': {'id': 2, 'name': 'Супруг(а)'},
#     'share': None,
#     'square': 37.9,
#     'type': {'id': 4, 'name': 'Квартира'}}],
#   'savings': [],
#   'spendings': [],
#   'stocks': [],
#   'vehicles': []}]

# %%
data = office.data

# %%
data[2010][0]['incomes']
# Out:
# [{'comment': '', 'relative': None, 'size': 1215654.67},
#  {'comment': '',
#   'relative': {'id': 2, 'name': 'Супруг(а)'},
#   'size': 295579.49}]
