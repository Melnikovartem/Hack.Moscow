# %%
import urllib
import json

# %%
class office_data:
    ask = "https://declarator.org/api/v1/search/sections/?office="
    
    def find_children(self):
        raise NotImplementedError
    
    def __init__(self, data):
        self.data = data

#     def __init__(self, office_id):
#         self.office_id = office_id
#         data_struct = {} 
#         data = {'next':self.ask+str(office_id)}

#         while data["next"]:
#             with urllib.request.urlopen(data["next"]) as url:
#                 data = json.loads(url.read().decode())
#             for i in data["results"]:
#                 if i["main"]["year"] not in data_struct:
#                     data_struct[i["main"]["year"]] = []
#                 data_struct[i["main"]["year"]].append(i)
#             print(data["next"])
# #         #надо обойти всех child и вызвать одну из функций sort
# #         child_list = self.find_children()
# #         for i in child_list:
# #             child_data = get_data_office(i)
# #             for j in child_data:
# #                 if j not in data_struct:
# #                     data_struct[j] = []
# #                 data_struct[j] += child_data[j]

#         self.data = data_struct # данные всех деклараций по годам
#         self.family = 0 # учитывать ли семью
        
    def true_avg(self, typ):
        years = self.data.keys()
        res = [0]  * len(years)
        for i, year in enumerate(years):
            curr_sum = 0
            curr_amount = 0
            for declaration in self.data[year]:
                for pep in declaration[typ]:
                    inc = pep['size']
                    if inc == inc:
                        curr_amount += 1
                        curr_sum += inc
            if curr_amount != 0:
                res[i] = curr_sum / curr_amount
        return res
        
    def gender_avg(self, typ):
        years = self.data.keys()
        males = [0] * len(years)
        females = [0] * len(years)
        for i, year in enumerate(years):
            male_sum = 0
            female_sum = 0
            male_amount = 0
            female_amount = 0
            for declaration in self.data[year]:
                gender = declaration['main']['person']['gender']
                for pep in declaration[typ]:
                    inc = pep['size']
                    if inc == inc:
                        if gender == 'M':
                            male_sum += inc
                            male_amount += 1
                        elif gender == 'F':
                            female_sum += inc
                            female_amount += 1
            if male_amount != 0:
                males[i] = male_sum / male_amount
            if female_amount != 0:
                females[i] = female_sum / female_amount
        return males, females
        
    def party_avg(self, typ):
        parties = set()
        years = self.data.keys()
        for year in years:
            for declaration in self.data[year]:
                party = declaration['main']['party']
                if party != party or party == None:
                    parties.add('Н.Д.')
                else:
                    parties.add(party['name'])
        res = {par : [0]*len(years) for par in parties}
        for i, year in enumerate(years):
            sums = {par : 0 for par in parties}
            amounts = {par : 0 for par in parties}
            for declaration in self.data[year]:
                party = declaration['main']['party']
                if party != party or party == None:
                    party = 'Н.Д.'
                else:
                    party = party['name']
                for pep in declaration[typ]:
                    inc = pep['size']
                    if inc == inc:
                        sums[party] += inc
                        amounts[party] += 1
            for party in parties:
                if amounts[party] != 0:
                    res[party][i] = sums[party] / amounts[party]
            
        return res
    #self.data - список по годам деклараций людей

# %%
office = office_data(data)
# office = office_data(12)

# %%
office.party_avg()
# Out:
# {'Н.Д.': [0, 0, 0, 0, 0, 0, 0, 2769537.14, 1567386.81, 1478636.39, 1445398.08],
#  'Единая Россия': [975657.0,
#   1063445.0,
#   1215654.67,
#   1397083.65,
#   1769658.0,
#   2213239.15,
#   3031778.9,
#   0,
#   0,
#   0,
#   0]}

# %%
data = office.data

# %%
data
# Out:
# {2008: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 975657.0},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 126437.0}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': {'id': 1, 'name': 'Единая Россия'},
#     'person': {'family_name': 'Тхакушинов',
#      'gender': 'M',
#      'given_name': 'Аслан',
#      'id': 1383,
#      'name': 'Тхакушинов Аслан Китович',
#      'patronymic_name': 'Китович'},
#     'year': 2008},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': 'садовый участок',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'relative': None,
#      'share': None,
#      'square': 1042.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'relative': None,
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'relative': None,
#      'share': None,
#      'square': 240.0,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'relative': None,
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'relative': None,
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'relative': None,
#      'share': None,
#      'square': 37.4,
#      'type': {'id': 2, 'name': 'Гараж'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 61.2,
#      'type': {'id': 4, 'name': 'Квартира'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}],
#  2009: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 1063445.0},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 146843.0}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': {'id': 1, 'name': 'Единая Россия'},
#     'person': {'family_name': 'Тхакушинов',
#      'gender': 'M',
#      'given_name': 'Аслан',
#      'id': 1383,
#      'name': 'Тхакушинов Аслан Китович',
#      'patronymic_name': 'Китович'},
#     'year': 2009},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': 'Садовый участок',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 1042.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 37.4,
#      'type': {'id': 2, 'name': 'Гараж'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Садовый домик',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 240.0,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 42.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 61.2,
#      'type': {'id': 4, 'name': 'Квартира'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}],
#  2010: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 1215654.67},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 295579.49}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': {'id': 1, 'name': 'Единая Россия'},
#     'person': {'family_name': 'Тхакушинов',
#      'gender': 'M',
#      'given_name': 'Аслан',
#      'id': 1383,
#      'name': 'Тхакушинов Аслан Китович',
#      'patronymic_name': 'Китович'},
#     'year': 2010},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': 'Садовый участок',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 1042.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 37.4,
#      'type': {'id': 2, 'name': 'Гараж'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Садовый домик',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 240.0,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 42.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 61.2,
#      'type': {'id': 4, 'name': 'Квартира'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}],
#  2011: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 1397083.65},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 313341.73}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': {'id': 1, 'name': 'Единая Россия'},
#     'person': {'family_name': 'Тхакушинов',
#      'gender': 'M',
#      'given_name': 'Аслан',
#      'id': 1383,
#      'name': 'Тхакушинов Аслан Китович',
#      'patronymic_name': 'Китович'},
#     'year': 2011},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': 'Садовый участок',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 1042.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 37.4,
#      'type': {'id': 2, 'name': 'Гараж'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Садовый домик',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 240.0,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 42.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 61.2,
#      'type': {'id': 4, 'name': 'Квартира'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}],
#  2012: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 1769658.0},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 340161.0}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': {'id': 1, 'name': 'Единая Россия'},
#     'person': {'family_name': 'Тхакушинов',
#      'gender': 'M',
#      'given_name': 'Аслан',
#      'id': 1383,
#      'name': 'Тхакушинов Аслан Китович',
#      'patronymic_name': 'Китович'},
#     'year': 2012},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 42.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 61.2,
#      'type': {'id': 4, 'name': 'Квартира'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}],
#  2013: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 2213239.15},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 516904.03}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': {'id': 1, 'name': 'Единая Россия'},
#     'person': {'family_name': 'Тхакушинов',
#      'gender': 'M',
#      'given_name': 'Аслан',
#      'id': 1383,
#      'name': 'Тхакушинов Аслан Китович',
#      'patronymic_name': 'Китович'},
#     'year': 2013},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 42.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 61.2,
#      'type': {'id': 4, 'name': 'Квартира'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}],
#  2014: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 3031778.9},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 576277.92}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': {'id': 1, 'name': 'Единая Россия'},
#     'person': {'family_name': 'Тхакушинов',
#      'gender': 'M',
#      'given_name': 'Аслан',
#      'id': 1383,
#      'name': 'Тхакушинов Аслан Китович',
#      'patronymic_name': 'Китович'},
#     'year': 2014},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 42.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 21, 'name': 'Долевая собственность'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': 0.5,
#      'square': 652.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 21, 'name': 'Долевая собственность'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': 0.5,
#      'square': 67.3,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 61.2,
#      'type': {'id': 4, 'name': 'Квартира'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}],
#  2015: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 2769537.14},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 626654.84}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': None,
#     'person': {'family_name': 'Тхакушинов',
#      'gender': 'M',
#      'given_name': 'Аслан',
#      'id': 1383,
#      'name': 'Тхакушинов Аслан Китович',
#      'patronymic_name': 'Китович'},
#     'year': 2015},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 652.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 67.3,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 61.2,
#      'type': {'id': 4, 'name': 'Квартира'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 42.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 21, 'name': 'Долевая собственность'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': 0.5,
#      'square': 652.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 3200.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 21, 'name': 'Долевая собственность'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': 0.5,
#      'square': 67.3,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 382.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 5, 'name': 'Безвозмездное пользование'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 726.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 61.2,
#      'type': {'id': 4, 'name': 'Квартира'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}],
#  2016: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 1567386.81},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 714475.03}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': None,
#     'person': {'family_name': 'Кумпилов',
#      'gender': 'M',
#      'given_name': 'Мурат',
#      'id': 543,
#      'name': 'Кумпилов Мурат Каральбиевич',
#      'patronymic_name': 'Каральбиевич'},
#     'year': 2016},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 59.0,
#      'type': {'id': 4, 'name': 'Квартира'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 15.9,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 27.7,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 852.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 278.9,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 15.9,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 27.7,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 852.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 852.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 852.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 278.9,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 278.9,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 278.9,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 15.9,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 15.9,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 15.9,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 27.7,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 27.7,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 27.7,
#      'type': {'id': 6, 'name': 'Иное'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': [{'brand': None,
#      'comment': '',
#      'manufacture_year': None,
#      'name': 'THULE MC-ATV',
#      'relative': None,
#      'type': {'id': 3, 'name': 'Автоприцеп'}}]}],
#  2017: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 1478636.39},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 154216.19}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': None,
#     'person': {'family_name': 'Кумпилов',
#      'gender': 'M',
#      'given_name': 'Мурат',
#      'id': 543,
#      'name': 'Кумпилов Мурат Каральбиевич',
#      'patronymic_name': 'Каральбиевич'},
#     'year': 2017},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 15.9,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 27.7,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 15.9,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 27.7,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}],
#  2018: [{'bonds': [],
#    'incomes': [{'comment': '', 'relative': None, 'size': 1445398.08},
#     {'comment': '',
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'size': 58086.77}],
#    'main': {'document_type': {'id': 1, 'name': 'Антикоррупционная декларация'},
#     'office': {'id': 12,
#      'name': 'Глава республики Адыгея',
#      'region': {'id': 3, 'name': 'Республика Адыгея'},
#      'type': {'id': 18, 'name': 'Региональный, без структуры'},
#      'url': 'http://www.adygheya.ru/president/status/index.shtml'},
#     'party': None,
#     'person': {'family_name': 'Кумпилов',
#      'gender': 'M',
#      'given_name': 'Мурат',
#      'id': 543,
#      'name': 'Кумпилов Мурат Каральбиевич',
#      'patronymic_name': 'Каральбиевич'},
#     'year': 2018},
#    'real_estates': [{'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 15.9,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 20, 'name': 'Индивидуальная'},
#      'region': None,
#      'relative': None,
#      'share': None,
#      'square': 27.7,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 15.9,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': 'Хозяйственное строение',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 2, 'name': 'Супруг(а)'},
#      'share': None,
#      'square': 27.7,
#      'type': {'id': 6, 'name': 'Иное'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 581.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 631.0,
#      'type': {'id': 1, 'name': 'Земельный участок'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}},
#     {'comment': '',
#      'country': 'Россия',
#      'name': '',
#      'own_type': {'id': 9, 'name': 'В пользовании'},
#      'region': None,
#      'relative': {'id': 3, 'name': 'Сын'},
#      'share': None,
#      'square': 323.8,
#      'type': {'id': 3, 'name': 'Жилой дом'}}],
#    'savings': [],
#    'spendings': [],
#    'stocks': [],
#    'vehicles': []}]}
